# %%
d
dfdfdDAD

# %%
data = {
    'Job Title': [
        'Data Scientist',
        'Software Engineer',
        'Product Manager',
        'UX Designer',
        'Cybersecurity Analyst'
    ],
    'Pay (USD/year)': [
        120000,
        110000,
        115000,
        95000,
        105000
    ],
    'Skill Count': [
        8,   # e.g., Python, SQL, ML, etc.
        10,  # e.g., Java, Git, REST, etc.
        7,   # e.g., Roadmapping, Communication, etc.
        6,   # e.g., Figma, Wireframing, etc.
        9    # e.g., Network Security, Python, etc.
    ]
}

# %%
df_dummy=pd.DataFrame(data)

# %%
df_dummy.plot(kind='scatter',x='Skill Count',y='Pay (USD/year)')
# Out:
# <Axes: xlabel='Skill Count', ylabel='Pay (USD/year)'>

# %%
df=df[df['job_title_short']=='Data Analyst']

# %%
df_exploded=df.explode('job_skills')
df_exploded
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
skill_stats=df_exploded.groupby('job_skills').agg(
    skill_count=('job_skills','count'),
    median_salary=('salary_year_avg','median')
)
skill_stats=skill_stats.sort_values(by='skill_count',ascending=False).head(10)
skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# sql               92428        92500.0
# excel             66860        84479.0
# python            57190        98500.0
# tableau           46455        95000.0
# power bi          39380        90000.0
# r                 29996        92527.5
# sas               27998        90000.0
# powerpoint        13822        85000.0
# word              13562        80000.0
# sap               11280        90000.0

# %%
skill_stats.plot(kind='scatter',x='skill_count',y='median_salary')
plt.xlabel('Count of job Postings for each skills')
plt.ylabel('Salary Yearly:Median')
plt.title('Salay vs Count of job postings for top 10 skills')
plt.tight_layout()
for i,txt in enumerate(skill_stats.index):
    print(i,txt)
    plt.text(skill_stats['skill_count'].iloc[i],skill_stats['median_salary'].iloc[i],txt)
plt.show()
# Out:
# 0 sql
# 1 excel
# 2 python
# 3 tableau
# 4 power bi
# 5 r
# 6 sas
# 7 powerpoint
# 8 word
# 9 sap

# %%
#https://www.youtube.com/watch?v=wUSDVGivd-8
#8h50m41s
